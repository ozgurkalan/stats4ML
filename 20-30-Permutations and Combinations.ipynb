# %% [markdown]
# # Permutations and Combinations

# %%
# environmental variables, settings and imports
# %run '000-env.ipynb'
# Out:
#     <style>
#         div#notebook-container    { width: 97%; }
#         div#menubar-container     { width: 90%; }
#         div#maintoolbar-container { width: 90%; }
#     </style>

# %% [markdown]
# ---

# %% [markdown]
# ## Permutation

# %% [markdown]
# A permutation is the number of ways we can arrange a set of things, and the order matters.

# %% [markdown]
# ## Combinations

# %% [markdown]
# A combination is the number of ways we can arrange a set of things, but the order doesn’t matter.

# %%
Image('data/permutation-combination in excel.png')

# %% [markdown]
# ## Resources

# %% [markdown]
# https://www.udemy.com/course/probability-and-statistics-for-business-and-data-science/learn/lecture/11062498#overview

# %% [markdown]
# https://www.udemy.com/course/statistics-probability/learn/lecture/9637570?start=1#overview

# %% [markdown]
# ## Examples

# %% [markdown]
# <span style='font-size:large; color:blue'>
# The possible permutations of letters a , b and c
# </span>

# %% [markdown]
# There is 6 possible permutation: **abc, bac, acb, bca, cab, cba**

# %%
# using python's math library
math.perm(3,3)
# where n=3 and k=3 (number of items or r)
# Out:
# 6

# %% [markdown]
# since **abc** and **cba** can be applied (order matters); $n!$ is the easy calculation.

# %%
# n!
math.factorial(3)
# Out:
# 6

# %%
# print all possibilities with itertools
import itertools
for c, i in enumerate(itertools.permutations(['a','b','c'])):
    print(c,i)
# Out:
# 0 ('a', 'b', 'c')
# 1 ('a', 'c', 'b')
# 2 ('b', 'a', 'c')
# 3 ('b', 'c', 'a')
# 4 ('c', 'a', 'b')
# 5 ('c', 'b', 'a')

# %%
# scipy: permutation
scipy.special.perm(3,3)
# Out:
# 6.0

# %%
# combinations of two pairs without order 
for c, i in enumerate(itertools.combinations(['a','b','c'],2)):
    print(c,i)
# Out:
# 0 ('a', 'b')
# 1 ('a', 'c')
# 2 ('b', 'c')

# %%
# scipy: combination without repetition
scipy.special.comb(N=3, k=2, repetition=False, exact=True)
# Out:
# 3

# %%
# combination with repetition
for c, i in enumerate(itertools.combinations_with_replacement(['a','b','c'],2)):
    print(c,i)
# Out:
# 0 ('a', 'a')
# 1 ('a', 'b')
# 2 ('a', 'c')
# 3 ('b', 'b')
# 4 ('b', 'c')
# 5 ('c', 'c')

# %%
# scipy: combination with repetition
scipy.special.comb(N=3, k=2, repetition=True, exact=True)
# Out:
# 6

# %% [markdown]
# .

# %% [markdown]
# <span style="font-size:large; color:blue">
# Password with 4 characters but no repeat
# </span>

# %% [markdown]
# A website requires a 4 character password.
# Characters can either be lowercase letters or the digits 0 9.
# You may **not repeat** a letter or number.
# How many different passwords can there be?

# %%
# 26 letters and 10 digits allowed
n = 36
# the number  of objects taken at onetime is 4
k = 4
'{:,}'.format(math.perm(36,4))
# Out:
# '1,413,720'

# %% [markdown]
# .

# %% [markdown]
# <span style="font-size:large; color:blue">
# Permutation: ice cream
# </span>

# %% [markdown]
# I have 4 scoops of ice cream: 1 chocolate, 1 strawberry, 1 vanilla, and 1 mint.
# I want to eat only 3 of the scoops.
# How many different ways can I eat 3 of the scoops if I consider both which scoops I eat and the order in which
# I eat them?

# %% [markdown]
# This is a permutation question, since I care about the order in which I eat the scoops.
# There are 4 total scoops, but I only want to eat 3 of them.

# %%
# permutation
math.perm(4,3)
# Out:
# 24

# %% [markdown]
# There are 24 different ways that I could eat 3 of the 4 scoops.
# For example, chocolate-strawberry-vanilla would be 1 of the 24 options,
# but since order matters, chocolate-vanilla-strawberry would be another option.

# %% [markdown]
# .

# %% [markdown]
# <span style="font-size:large; color:blue">
# Combination: ice cream
# </span>

# %% [markdown]
# I have the same 4 scoops of ice cream: 1 chocolate, 1 strawberry, 1 vanilla, and 1 mint.
# I want to eat only 3 of the scoops,
# and I don’t care about the order in which I eat my 3 scoops.
# How many different combinations of 3 scoops can I create?

# %% [markdown]
# This is a combination question, since I don’t care about the order in which I eat the scoops.
# There are 4 total scoops, but I only want to eat 3 of them.

# %%
# combination
math.comb(4,3)
# Out:
# 4

# %% [markdown]
# There are 4 different ways that I could eat 3 of the 4 scoops.
# For example, chocolate-strawberry-vanilla would be 1 of the 4 options,
# but since order doesn’t matter,
# chocolate-vanilla-strawberry would be the same combination, and wouldn’t count as another one of the 4 combinations.

# %% [markdown]
# .

# %% [markdown]
# <span style='font-size:large; color:blue'>
# Car plate: permutation with repetition
# </span>

# %% [markdown]
# How many 4 digit license plates can you make using the numbers 0 to 9 while allowing **repetition**?

# %% [markdown]
# There are 10 objects taken 4 at a time.

# %% [markdown]
# formula for permutation with repetition: $n^r$

# %%
# repeating permutations
10**4
# Out:
# 10000

# %% [markdown]
# 10 thousand permutations like 1234, 1335, 1555

# %% [markdown]
# .
