# %%
# %run 000-env.ipynb
# Out:
#     <style>
#         div#notebook-container    { width: 97%; }
#         div#menubar-container     { width: 90%; }
#         div#maintoolbar-container { width: 90%; }
#     </style>

# %%
x = np.linspace(stats.norm.ppf(0.01),
                stats.norm.ppf(0.99), 100)

fig, ax = plt.subplots(1, 1)
ax.plot(x, stats.norm.pdf(x),
       'r-', lw=4, alpha=0.8, label='norm pdf')

# %%
uni_rv = np.zeros(10)
for i in np.arange(10):
    uni_rv[i] = np.random.uniform(10,20)
uni_rv
# Out:
# array([19.33912299, 14.64470303, 13.74559841, 12.48449503, 12.45783685,
#        10.47105668, 18.16738774, 11.91856842, 13.42810131, 17.05298182])

# %%
plt.hist(stats.norm.rvs(size=1000,loc=0, scale=1), bins=100, density=1)
plt.show()

# %%
plt.hist(np.random.randn(1000), bins=100, log=False)
plt.show()

# %%
round(stats.binom.sf(1,10,0.08), 3)
# Out:
# 0.188

# %%
# %8 colorblind, take 10 people from a class
n=10
p=0.08
x= range(n+1)
Y= stats.binom.pmf(x,n,p)
plt.plot(x, Y, 'r-o')

# %%
n=stats.bernoulli(12/20).rvs(20)
plt.bar(n, stats.bernoulli(12/20).pmf(n))
plt.xlim([0,1]);
plt.xticks([0,1]);

# %%
sns.displot(stats.bernoulli.rvs(size=20,p=12/20), kde=True)

# %%
sns.displot(stats.bernoulli.rvs(size=500,p=0.5), kde=True)

# %%
percentage(48,100,5)
# Out:
# 48.0

# %%
np.ptp(np.arange(10))
# Out:
# 9
