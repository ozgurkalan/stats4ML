# %% [markdown]
# # Normal Distribution - Gaussian

# %%
# environmental variables, settings and imports
# %run '000-env.ipynb'
# Out:
#     <style>
#         div#notebook-container    { width: 97%; }
#         div#menubar-container     { width: 90%; }
#         div#maintoolbar-container { width: 90%; }
#     </style>

# %% [markdown]
# ---

# %% [markdown]
# A **Normal or Gaussian Distribution** is defined by its mean and standard deviation. The data values are spread around the mean value, and the standard deviation controls the spread. A Gaussian distribution has most data values around the mean or center value.

# %% [markdown]
# <div class='row'>
# <div class='col-sm-6'>
#     <img src="data/normal-dist-01.png" width=500>
# </div>
# <div class='col-sm-6'>
#       <img src="data/normal-dist-02.png" width=500>
# </div>
# </div>

# %% [markdown]
# Many real life data points follow a normal distribution:
# * People's Heights and Weights
# * Population Blood Pressure
# * Test Scores
# * Measurement Errors

# %% [markdown]
# * the probability of a **specific outcome is zero**
# * we can only find probabilities over *a specified interval or range* of outcomes
# * always symmetrical, asymmetrical curves display skew and are not normal
# * Unlike discrete distributions, where the sum of all the bars equals one,
# in a normal distribution the area under the curve equals one

# %% [markdown]
# <img src="data/normal-dist-03.png" width=800 align='left'>

# %% [markdown]
# ## Standard Normal Distribution

# %% [markdown]
# The **standard normal distribution** is a special case of the normal distribution with
# a mean equal to zero, $\mu=$, and a standard deviation (or variance) equal to one, $\sigma=1$.

# %% [markdown]
# ---

# %% [markdown]
# ## Resources

# %% [markdown]
# https://courses.lumenlearning.com/introstats1/chapter/the-standard-normal-distribution/

# %% [markdown]
# https://www.wolframalpha.com/input/?i=normal+distribution

# %% [markdown]
# [Is My Data Normal? - Brandon Foltz - YouTube Video](https://youtu.be/9IcaQwQkE9I)

# %% [markdown]
# .

# %%
youGrid('RKdB1d5-OE0', '9IcaQwQkE9I')
# Out:
# GridspecLayout(children=(Output(layout=Layout(grid_area='widget001')), Output(layout=Layout(grid_area='widget0…

# %% [markdown]
# .

# %% [markdown]
# ## Examples

# %% [markdown]
# <span style="font-size:large;color:blue">
# Normal Distribution - Sample Plot with PPF
# </span>

# %% [markdown]
# Use **PPF** for upper and lower boundaries for a plot. Both ends are endless, but good practice is to display between Point of Percentage. PPF is the inverse of CDF

# %%
# x-axis: 100 evenly spaced numbers between the lowest boundary at 1% and upper boundary at 99%
x = np.linspace(stats.norm.ppf(0.01),
                stats.norm.ppf(0.99), 100)

# y- axis: PDF function of a normal distribution for x
y = stats.norm.pdf(x)

fig, ax = plt.subplots(1, 1, figsize=(16,4))
ax.plot(x, y, 'r-', lw=4, alpha=0.8)
plt.show();

# %% [markdown]
# ## Normal Distribution with Scipy

# %%
# Set the mean
mean = 0

#Set the standard deviation
std = 1


# Create a range
X = np.arange(-4,4,0.01)

#Create the normal distribution for the range
Y = stats.norm.pdf(X,mean,std)

#
plt.plot(X,Y)
plt.show();

# %% [markdown]
# ## Normal Distribution with Numpy

# %%
#Set the mean and the standard deviation
mu, sigma = 0,0.1

# grab 1000 random numbers from the normal distribution
norm_set = np.random.normal(mu,sigma,1000)

sns.histplot(norm_set, bins=10, kde=True)
plt.show();

# %% [markdown]
# ## Introduction to Statistics With Python - Thomas Haslwanter - Book

# %% [markdown]
# rest of the samples are from the book's Github site: https://github.com/thomas-haslwanter/statsintro_python

# %% [markdown]
# ## Different Representations

# %%
''' Different aspects of a normal distribution'''
# Generate the data
x = np.r_[-10:10:0.1]
rv = stats.norm(0,1)   # random variate

x2 = np.r_[0:1:0.001]

ax = plt.subplot2grid((3,2),(0,0), colspan=2)
plt.plot(x,rv.pdf(x))
plt.xlim([-10,10])
plt.title('Normal Distribution - PDF')

plt.subplot(323)
plt.plot(x,rv.cdf(x))
plt.xlim([-4,4])
plt.title('CDF: cumulative distribution fct')

plt.subplot(324)
plt.plot(x,rv.sf(x))
plt.xlim([-4,4])
plt.title('SF: survival fct')

plt.subplot(325)
plt.plot(x2,rv.ppf(x2))
plt.title('PPF')

plt.subplot(326)
plt.plot(x2,rv.isf(x2))
plt.title('ISF')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Shifted distribution

# %%
'''PDF, scatter plot, and histogram.'''
# Generate the data
x = np.arange(-5,15,0.1)
# Plot a normal distribution: "Probability density functions"
myMean = 5
mySD = 2
y = stats.norm(myMean, mySD).pdf(x)
plt.plot(x,y)
plt.title('Shifted Normal Distribution')
# Out:
# Text(0.5, 1.0, 'Shifted Normal Distribution')

# %% [markdown]
# ## Random numbers with a normal distribution

# %%
numData = 500
data = stats.norm.rvs(myMean, mySD, size = numData)
plt.plot(data, '.')
plt.title('Normally distributed data')
plt.show()

plt.hist(data)
plt.title('Histogram of normally distributed data')
# Out:
# Text(0.5, 1.0, 'Histogram of normally distributed data')

# %% [markdown]
# ## Multiple normal sample distributions

# %%
'''Show multiple samples from the same distribution, and compare means.'''
# Do this 25 times, and show the histograms
numRows = 5
numData = 100
for ii in range(numRows):
    for jj in range(numRows):
        data = stats.norm.rvs(myMean, mySD, size=numData)
        plt.subplot(numRows,numRows,numRows*ii+jj+1)
        plt.hist(data)

        plt.xticks([])
        plt.yticks([])
        plt.xlim(myMean-3*mySD, myMean+3*mySD)

plt.tight_layout()
plt.show()

# Check out the mean of 1000 normally distributded samples
numTrials = 1000;
numData = 100
myMeans = np.ones(numTrials)*np.nan
for ii in range(numTrials):
    data = stats.norm.rvs(myMean, mySD, size=numData)
    myMeans[ii] = np.mean(data)
print('The standard error of the mean, with {0} samples, is {1:5.3f}'.format(numData, np.std(myMeans, ddof=1)))
# Out:
# The standard error of the mean, with 100 samples, is 0.192

# %% [markdown]
# ## Normality Check

# %%
'''Check if the distribution is normal.'''
# Generate and show a distribution
numData = 100
data = stats.norm.rvs(myMean, mySD, size=numData)
plt.hist(data)
# Out:
# (array([ 2.,  4.,  4., 13., 18., 25., 17., 15.,  1.,  1.]),
#  array([-1.37912252, -0.1967862 ,  0.98555012,  2.16788645,  3.35022277,
#          4.5325591 ,  5.71489542,  6.89723175,  8.07956807,  9.2619044 ,
#         10.44424072]),
#  <BarContainer object of 10 artists>)

# %%
# Graphical test: if the data lie on a line, they are pretty much
# normally distributed
_ = stats.probplot(data, plot=plt)

# %% [markdown]
# ### Normal Test with Scipy

# %%
# The scipy "normaltest" is based on D’Agostino and Pearson’s test that
# combines skew and kurtosis to produce an omnibus test of normality.
_, pVal = stats.normaltest(data)

# Or you can check for normality with Kolmogorov-Smirnov test: but this is only advisable for large sample numbers!
#_,pVal = stats.kstest((data-np.mean(data))/np.std(data,ddof=1), 'norm')

if pVal > 0.05:
    print('Data are probably normally distributed')
# Out:
# Data are probably normally distributed

# %% [markdown]
# ## Values from the Cumulative Distribution Function

# %%
'''Calculate an empirical cumulative distribution function, compare it with the exact one, and
find the exact point for a specific data value.'''

# Generate normally distributed random data
myMean = 5
mySD = 2
numData = 1000
data = stats.norm.rvs(myMean, mySD, size=numData)

# Calculate the cumulative distribution function, CDF
numbins = 20
counts, bin_edges = np.histogram(data, bins=numbins, density=True)
cdf = np.cumsum(counts)
cdf /= max(cdf)

# compare with the exact CDF
plt.plot(bin_edges[1:],cdf)
plt.plot(x, stats.norm.cdf(x, myMean, mySD),'r')

# Find out the value corresponding to the x-th percentile: the
# "cumulative distribution function"
value = 2
myMean = 5
mySD = 2
cdf = stats.norm.cdf(value, myMean, mySD)
print(('With a threshold of {0:4.2f}, you get {1}% of the data'.format(value, round(cdf*100))))

# For the percentile corresponding to a certain value: 
# the "inverse cumulative distribution function" 
value = 0.025
icdf = stats.norm.isf(value, myMean, mySD)
print('To get {0}% of the data, you need a threshold of {1:4.2f}.'.format((1-value)*100, icdf))
# Out:
# With a threshold of 2.00, you get 7% of the data
# To get 97.5% of the data, you need a threshold of 8.92.
